# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

# %%
# %run 00_process_json_files

# %%
# %run 01_process_audio_files

# %%
# %run 02_enrich_data

# %%
# %run 03_create_calendar_data

# %%
# %run 04_generate_and_multiple_data
